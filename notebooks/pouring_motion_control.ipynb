# %% [markdown]
# # Robotic Pouring Motion Control
# ## Gymnasium Simulation & Reinforcement Learning Benchmarks
#
# This notebook provides an interactive environment to explore the **RoboticPouringEnv** Gymnasium simulation, evaluate trained **PPO** and **SAC** policies, and compare them against **PID** and **Rule-Based** control baselines.

# %%
from pouring_sim.environment import RoboticPouringEnv

# Instantiate environment
env = RoboticPouringEnv(target_volume=200.0)
obs, info = env.reset(seed=42)
print("Initial Observation:", obs)
print("Environment Metadata:", info)
